# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/IS/spider
# Out:
# /content/drive/MyDrive/IS/spider

# %%
# !python k_order.py
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/IS/spider/k_order.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_out = df_out.append(s, ignore_index=True)
# /content/drive/MyDrive/IS/spider/k_order.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_out = df_out.append(s, ignore_index=True)
# /content/drive/MyDrive/IS/spider/k_order.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_out = df_out.append(s, ignore_index=True)
# /content/drive/MyDrive/IS/spider/k_order.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_out = df_out.append(s, ignore_index=True)
# ...
